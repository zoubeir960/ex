# %%
import numpy as np
import pandas as pd
import seaborn as sns
from scipy import stats as st
import matplotlib.pyplot as plt
from matplotlib.ticker import PercentFormatter
from scipy.stats import chi2_contingency
from collections import Counter
from math import sqrt

# %%
df = pd.read_excel(r'C:\Users\hp\Desktop\basefinal\datafinale.xlsx') 
df
# Out:
#           ID_ORDER   DATE-ADD            TIME-ADD             HOUR  SEASON  \
# 0         80143573 2018-01-01 2018-01-01 16:03:37   Late_afternoon  Winter
# 1         80143576 2018-01-01 2018-01-01 17:38:26   Late_afternoon  Winter
# 2         80143572 2018-01-01 2018-01-01 14:52:08  Early_afternoon  Winter
# 3         80143574 2018-01-01 2018-01-01 16:56:04   Late_afternoon  Winter
# 4         80143575 2018-01-01 2018-01-01 17:27:18   Late_afternoon  Winter
# ...            ...        ...                 ...              ...     ...
# 669374  1300225885 2021-07-04 2021-07-04 12:27:16  Early_afternoon  Summer
# 669375  1300225883 2021-07-04 2021-07-04 11:02:34     Late_morning  Summer
# 669376  1300225886 2021-07-04 2021-07-04 14:34:13  Early_afternoon  Summer
# 669377    14156247 2021-07-04 2021-07-04 15:07:42   Late_afternoon  Summer
# 669378   640092595 2021-07-04 2021-07-04 18:45:32          Evening  Summer
#
# ...

# %%
df.shape
# Out:
# (669379, 37)

# %%
df.describe()
# Out:
#            ID_ORDER          score            AGE  TOTAL_QUANTITY  \
# count  6.693790e+05  669314.000000  158128.000000   669379.000000
# mean   2.632637e+08       0.474165      41.060432        2.224686
# std    3.757125e+08       0.485189       9.907106        2.061886
# min    4.000000e+00       0.000000       0.000000        1.000000
# 25%    2.819448e+07       0.000000      34.000000        1.000000
# 50%    5.413727e+07       0.000000      40.000000        2.000000
# 75%    6.400770e+08       1.000000      47.000000        2.000000
# max    1.340099e+09       1.000000     100.000000      468.000000
#
#         TOTAL_TICKET    TOTAL_PRICE  TOTAL_REDUCTION  TOTAL_REDUCTION_PERCENT
# count  669379.000000  669379.000000    669379.000000            669379.000000
# mean      119.022604     211.093426        92.070822                40.996006
# std       117.338698     206.832467       109.924243                19.523808
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 669379 entries, 0 to 669378
# Data columns (total 37 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   ID_ORDER                    669379 non-null  int64
#  1   DATE-ADD                    669379 non-null  datetime64[ns]
#  2   TIME-ADD                    669379 non-null  datetime64[ns]
#  3   HOUR                        669379 non-null  object
#  4   SEASON                      669379 non-null  object
#  5   P_MONTH                     669379 non-null  object
#  6   P_WEEK                      669379 non-null  object
#  7   COVID                       669379 non-null  object
#  8   CONFINEMENT                 669379 non-null  object
#  9   CURFEW                      669379 non-null  object
#  10  LOCATION                    669379 non-null  object
#  11  ID_CUSTOMER                 669379 non-null  object
# ...

# %%
df['TOTAL_REDUCTION_PERCENT'].value_counts()
# Out:
# 30.000000    65779
# 50.000000    60578
# 70.000000    52209
# 0.000000     47880
# 40.000000    35003
#              ...
# 51.728017        1
# 29.483304        1
# 57.264232        1
# 63.838430        1
# 37.063161        1
# Name: TOTAL_REDUCTION_PERCENT, Length: 83395, dtype: int64

# %%
df['TOTAL_PRICE'].value_counts()
# Out:
# 89.9      29084
# 79.9      26908
# 98.9      26334
# 159.8     17889
# 69.9      17599
#           ...
# 555.8         1
# 613.1         1
# 491.2         1
# 1956.8        1
# 964.6         1
# Name: TOTAL_PRICE, Length: 13857, dtype: int64

# %%
df['TOTAL_QUANTITY'].value_counts()
# Out:
# 2      274612
# 1      240324
# 3       69479
# 4       44279
# 6       13634
#         ...
# 52          1
# 51          1
# 48          1
# 45          1
# 468         1
# Name: TOTAL_QUANTITY, Length: 70, dtype: int64

# %%
df['AGE'].value_counts()
# Out:
# 38.0    7756
# 39.0    7260
# 41.0    7108
# 40.0    7072
# 42.0    6265
#         ...
# 86.0       2
# 90.0       2
# 87.0       1
# 98.0       1
# 88.0       1
# Name: AGE, Length: 99, dtype: int64

# %%
#Finding Missing Values
import matplotlib.pyplot as plt
import seaborn as sns
fig, ax = plt.subplots(figsize=(10,5))
sns.heatmap(df.isnull(), cbar=False, cmap="YlGnBu_r")
plt.show()

# %%
df.isnull().sum()
# Out:
# ID_ORDER                           0
# DATE-ADD                           0
# TIME-ADD                           0
# HOUR                               0
# SEASON                             0
# P_MONTH                            0
# P_WEEK                             0
# COVID                              0
# CONFINEMENT                        0
# CURFEW                             0
# LOCATION                           0
# ID_CUSTOMER                        0
# lastname                           0
# firstname                     340935
# CUSTOMER_DESCRIPTION          119554
# gender                        341566
# score                             65
# BIRTHDAY                      511251
# AGE                           511251
# AGE_SEGMENT                   511264
# TELEX                         346412
# EMAIL                         543950
# ADRESS                        464989
# POSTAL_CODE                   129278
# CITY                          130294
# ...

# %%
fig,ax = plt.subplots(figsize=(15,15))
sns.countplot(ax = ax, x='TOTAL_QUANTITY',data=df)
plt.show()

# %%
sns.distplot(df['AGE'])
plt.show()
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df.shape
# Out:
# (669379, 37)

# %%
embarked_count=[158128,322967,125429,204390,327813]
department_left=['AGE','TELEX','EMAIL','ADRESS','gender']
explode=[0,0.1,0.2,0.1,0.1]
fig1, ax1 = plt.subplots(figsize=(10,10))
ax1.pie(embarked_count, explode=explode,labels=department_left,autopct='%1.1f%%',
        shadow=True, startangle=150)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
df['AREA'].value_counts()
# Out:
# urbaine    535319
# rurale        162
# Name: AREA, dtype: int64

# %%
#AREA
import matplotlib.pyplot as plt

# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = ['urbaine', 'rurale']
count=[ 535319 , 162]
explode = (0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots(figsize=(10,10))
ax1.pie(count, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
df['CLASS'].value_counts()
# Out:
# B     448910
# C+     45921
# C-     21834
# A      16643
# D       2142
# E         31
# Name: CLASS, dtype: int64

# %%
#CLASS
import matplotlib.pyplot as plt

# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = ['B', 'C+', 'C-', 'A','D','E']
count=[  448910, 45921,21834,16643,2142,31]
explode = (0, 0.1, 0, 0,0,0.2)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots(figsize=(10,10))
ax1.pie(count, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=False, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
df['REGION'].value_counts()
# Out:
# Grand-Tunis     386182
# nord-est         70522
# centre-est       38794
# sud-est          13431
# nord-ouest       11452
# centre-ouest     10169
# sud-ouest         4931
# Name: REGION, dtype: int64

# %%
#region
import matplotlib.pyplot as plt

# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = ['Grand-Tunis', 'nord-est', 'centre-est', 'sud-est','nord-ouest','centre-ouest','sud-ouest']
count=[ 386182 , 70522,38794,13431, 11452,10169,4931]
explode = (0, 0.1, 0, 0,0,0.2,0.3)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots(figsize=(10,10))
ax1.pie(count, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
df['AGE_SEGMENT'].value_counts()
# Out:
# entre 40 et 50 ans    53041
# entre 35 et 40 ans    34141
# Plus de 50 ans        25761
# entre 30 et 35 ans    23676
# entre 25 et 30 ans    14230
# Moins de 25 ans        7266
# Name: AGE_SEGMENT, dtype: int64

# %%
#AGE_SEGMENT
import matplotlib.pyplot as plt

# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = ['entre 40 et 50 ans', 'entre 35 et 40 ans', 'Plus de 50 ans', 'entre 30 et 35 ans','entre 25 et 30 ans','Moins de 25 ans']
count=[  53041 , 34141,25761,23676, 14230,7266]
explode = (0, 0.1, 0, 0,0,0.2)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots(figsize=(10,10))
ax1.pie(count, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
df['TOTAL_QUANTITY_SEGMENTS'].value_counts()
# Out:
# 2 pièces                274612
# 1 pièce                 240324
# Entre 3 et 5 Pièces     122919
# Entre 6 et 10 Pièces     26371
# Plus que 10 Pièces        5153
# Name: TOTAL_QUANTITY_SEGMENTS, dtype: int64

# %%
#TOTAL_QUANTITY_SEGMENTS
import matplotlib.pyplot as plt

# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = ['2 pièces', '1 pièce', 'Entre 3 et 5 Pièces', 'Entre 6 et 10 Pièces','Plus que 10 Pièces']
count=[   274612 , 240324,122919,26371,  5153]
explode = (0, 0.1, 0, 0,0)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots(figsize=(10,10))
ax1.pie(count, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=80)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
df['REDUCTION_PERCENT_SEGMENTS'].value_counts()
# Out:
# de 40 à 50%        174124
# Plus que 50%       171114
# Inférieur à 30%    160366
# de 30 à 40%        113761
# Sans remise         50014
# Name: REDUCTION_PERCENT_SEGMENTS, dtype: int64

# %%
#REDUCTION_PERCENT_SEGMENTS
import matplotlib.pyplot as plt

# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = ['de 40 à 50%', 'Plus que 50%', 'Inférieur à 30%', 'de 30 à 40%','Sans remise']
count=[   174124 , 171114,160366,113761,  50014]
explode = (0, 0.1, 0, 0,0)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots(figsize=(10,10))
ax1.pie(count, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=80)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
df['TICKET_VALUE'].value_counts()
# Out:
# Inférieur à 100 DT     367639
# Entre 100 et 200 DT    208165
# Entre 200 et 300 DT     60348
# Supérieur à 300 DT      33227
# Name: TICKET_VALUE, dtype: int64

# %%
#TICKET_VALUE
import matplotlib.pyplot as plt

# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = ['Inférieur à 100 DT', 'Entre 100 et 200 DT', 'Entre 200 et 300 DT', 'Supérieur à 300 DT']
count=[   367639 , 208165,60348,33227]
explode = (0, 0.1, 0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots(figsize=(10,10))
ax1.pie(count, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=80)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns 
fig,ax = plt.subplots(figsize=(30,20))
sns.barplot(ax= ax, x = df['LOCATION'].value_counts().head(10).index, y=df['LOCATION'].value_counts().head(10))
plt.ylabel('Frequency')
plt.title('Most Popular Items')
sns.set(font_scale=1.3)
plt.show()

# %%
fig = plt.figure(figsize=(15,7))
sns.countplot(x='CONFINEMENT',data=df)
plt.show()

# %%
df['CONFINEMENT'].value_counts()
# Out:
# NON    433251
# NO     235181
# YES       947
# Name: CONFINEMENT, dtype: int64

# %%
df['COVID'].value_counts()
# Out:
# Pre-Covid     462964
# Post-Covid    206415
# Name: COVID, dtype: int64

# %%
fig = plt.figure(figsize=(15,7))
sns.countplot(x='COVID',data=df)
plt.show()

# %%
df['SEASON'].value_counts()
# Out:
# Winter    203771
# Summer    188867
# Spring    152466
# Autumn    124275
# Name: SEASON, dtype: int64

# %%
fig = plt.figure(figsize=(15,7))
sns.countplot(x='SEASON',data=df)
plt.show()

# %%
df['P_MONTH'].value_counts()
# Out:
# End_of_Month       240896
# Start_of_Month     216387
# Middle_of_Month    212096
# Name: P_MONTH, dtype: int64

# %%
fig = plt.figure(figsize=(15,7))
sns.countplot(x='P_MONTH',data=df)
plt.show()

# %%
df['HOUR'].value_counts()
# Out:
# Early_afternoon    196838
# Late_afternoon     191090
# Evening            160411
# Late_morning       101862
# Night               16986
# Early_morning        2192
# Name: HOUR, dtype: int64

# %%
fig = plt.figure(figsize=(20,10))
sns.countplot(x='HOUR',data=df)
plt.show()

# %%
df['P_WEEK'].value_counts()
# Out:
# Mid_Week         272553
# Week_End         241640
# Start_of_Week    155186
# Name: P_WEEK, dtype: int64

# %%
fig = plt.figure(figsize=(10,10))
sns.countplot(x='P_WEEK',data=df)
plt.show()

# %%
g=sns.FacetGrid(df,col='COVID')
g.map(sns.countplot, 'gender')
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\axisgrid.py:645: UserWarning: Using the countplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
g=sns.FacetGrid(df,col='SEASON')
g.map(sns.countplot, 'gender')
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\axisgrid.py:645: UserWarning: Using the countplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
g=sns.FacetGrid(df,col='P_WEEK')
g.map(sns.countplot, 'gender')
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\axisgrid.py:645: UserWarning: Using the countplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
g=sns.FacetGrid(df,col='P_MONTH',height=5)
g.map(sns.countplot, 'gender')
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\axisgrid.py:645: UserWarning: Using the countplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
g=sns.FacetGrid(df,col='HOUR',height=3)
g.map(sns.countplot, 'gender')
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\axisgrid.py:645: UserWarning: Using the countplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
df['CURFEW'].value_counts()
# Out:
# NON            433251
# NO             111237
# de 20h à 5h     55017
# de 22h à 5h     39934
# de 19h à 5h     15189
# de 23h à 5h     10051
# de 21h à 5h      3629
# de 18h à 6h      1071
# Name: CURFEW, dtype: int64
